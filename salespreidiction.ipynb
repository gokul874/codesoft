# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as style
import warnings
warnings.filterwarnings('ignore')

# %%
ad = pd.read_csv("advertising.csv")
ad.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
ad.shape
# Out:
# (200, 4)

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
ad.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
ad.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
ad.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
fig,axs=plt.subplots(1,1)
plt1=sns.boxplot(ad['Radio'],ax=axs)

# %%
fig,axs=plt.subplots(1,1)
plt1=sns.boxplot(ad['TV'],ax=axs)

# %%
fig,axs=plt.subplots(1,1)
plt1=sns.boxplot(ad['Sales'],ax=axs)

# %%
fig,axs=plt.subplots(1,1)
plt1=sns.boxplot(ad['Newspaper'],ax=axs)

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(data=ad,x=ad['TV'],y=ad['Sales'])
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(data=ad,x=ad['Radio'],y=ad['Sales'])
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(data=ad,x=ad['Newspaper'],y=ad['Sales'])
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
df_corr=ad.corr()

# %%
plt.figure(figsize=(8,5))
sns.heatmap(df_corr,annot=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
features = ad[['TV', 'Radio', 'Newspaper']]
target = ad[['Sales']]

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, train_size = .8)

# %%
print('Target for train: ', y_train.shape)
print('Target for test: ', y_test.shape)
print('Train set of features: ', X_train.shape)
print('Test set of features: ', X_test.shape)
# Out:
# Target for train:  (160, 1)
# Target for test:  (40, 1)
# Train set of features:  (160, 3)
# Test set of features:  (40, 3)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([[10.46196312],
#        [16.90736126],
#        [ 8.77564539],
#        [ 7.63976024],
#        [24.74682272],
#        [21.52066525],
#        [11.38217628],
#        [18.80665957],
#        [19.02008809],
#        [24.87598645],
#        [12.32674385],
#        [20.777346  ],
#        [ 5.83004622],
#        [16.60887916],
#        [12.07218011],
#        [10.22029968],
#        [10.79231955],
#        [ 8.18236619],
#        [15.3693877 ],
#        [12.94409829],
#        [10.56903516],
#        [18.96930911],
#        [20.61783148],
#        [18.26838213],
#        [ 8.79448448],
#        [15.89861033],
#        [21.45797209],
#        [21.96572473],
#        [ 9.6470035 ],
#        [ 9.52889825],
#        [20.89118581],
#        [10.7871596 ],
#        [11.74046531],
#        [18.99033047],
#        [ 6.14096785],
#        [12.53754098],
#        [20.17589729],
#        [17.23153966],
#        [13.75610777],
#        [20.27841882]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_pred, y_test)
# Out:
# 2.0933696904534402

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9123672186339177

# %% [markdown]
# Thank you!!
